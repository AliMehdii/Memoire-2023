# %%
import os
import numpy as np
import pandas as pd

# %%
data = []
Home = 'C:/Users/alime/Dropbox/PC/Documents/Coding/Memoire 2023/Datasets/Brain-Tumor-Dataset-RAW/Cropped_Image_Sets/train'
for folder in sorted(os.listdir('C:/Users/alime/Dropbox/PC/Documents/Coding/Memoire 2023/Datasets/Brain-Tumor-Dataset-RAW/Cropped_Image_Sets/train')):
    for file in sorted(os.listdir('C:/Users/alime/Dropbox/PC/Documents/Coding/Memoire 2023/Datasets/Brain-Tumor-Dataset-RAW/Cropped_Image_Sets/train/'+folder)):
        file_path = Home + '/' + folder + '/' + file

        file_name = file.split('.')[0]
        data.append([file_name, folder, file_path])

train_set = pd.DataFrame(data, columns=['File_Name', 'Folder', 'File_Path'])
print(train_set)
train_set.to_csv('Train_set.csv')
# Out:
#           File_Name                   Folder  \
# 0     G1001_cropped           glioma_cropped
# 1     G1002_cropped           glioma_cropped
# 2     G1003_cropped           glioma_cropped
# 3     G1006_cropped           glioma_cropped
# 4     G1007_cropped           glioma_cropped
# ...             ...                      ...
# 2139    P96_cropped  pituitary_tumor_cropped
# 2140    P97_cropped  pituitary_tumor_cropped
# 2141    P98_cropped  pituitary_tumor_cropped
# 2142    P99_cropped  pituitary_tumor_cropped
# 2143     P9_cropped  pituitary_tumor_cropped
#
#                                               File_Path
# 0     C:/Users/alime/Dropbox/PC/Documents/Coding/Mem...
# 1     C:/Users/alime/Dropbox/PC/Documents/Coding/Mem...
# 2     C:/Users/alime/Dropbox/PC/Documents/Coding/Mem...
# 3     C:/Users/alime/Dropbox/PC/Documents/Coding/Mem...
# 4     C:/Users/alime/Dropbox/PC/Documents/Coding/Mem...
# ...                                                 ...
# ...

# %%
data = []
Home = 'C:/Users/alime/Dropbox/PC/Documents/Coding/Memoire 2023/Datasets/Brain-Tumor-Dataset-RAW/Cropped_Image_Sets/val'
for folder in sorted(os.listdir('C:/Users/alime/Dropbox/PC/Documents/Coding/Memoire 2023/Datasets/Brain-Tumor-Dataset-RAW/Cropped_Image_Sets/val')):
    for file in sorted(os.listdir('C:/Users/alime/Dropbox/PC/Documents/Coding/Memoire 2023/Datasets/Brain-Tumor-Dataset-RAW/Cropped_Image_Sets/val/'+folder)):
        file_path = Home + '/' + folder + '/' + file

        file_name = file.split('.')[0]
        data.append([file_name, folder, file_path])

val_set = pd.DataFrame(data, columns=['File_Name', 'Folder', 'File_Path'])
print(val_set)
val_set.to_csv('Val_set.csv')
# Out:
#          File_Name                   Folder  \
# 0    G1000_cropped           glioma_cropped
# 1    G1004_cropped           glioma_cropped
# 2    G1013_cropped           glioma_cropped
# 3     G101_cropped           glioma_cropped
# 4    G1022_cropped           glioma_cropped
# ..             ...                      ...
# 453   P910_cropped  pituitary_tumor_cropped
# 454   P911_cropped  pituitary_tumor_cropped
# 455   P919_cropped  pituitary_tumor_cropped
# 456    P91_cropped  pituitary_tumor_cropped
# 457   P922_cropped  pituitary_tumor_cropped
#
#                                              File_Path
# 0    C:/Users/alime/Dropbox/PC/Documents/Coding/Mem...
# 1    C:/Users/alime/Dropbox/PC/Documents/Coding/Mem...
# 2    C:/Users/alime/Dropbox/PC/Documents/Coding/Mem...
# 3    C:/Users/alime/Dropbox/PC/Documents/Coding/Mem...
# 4    C:/Users/alime/Dropbox/PC/Documents/Coding/Mem...
# ..                                                 ...
# ...

# %%
data = []
Home = 'C:/Users/alime/Dropbox/PC/Documents/Coding/Memoire 2023/Datasets/Brain-Tumor-Dataset-RAW/Cropped_Image_Sets/test'
for folder in sorted(os.listdir('C:/Users/alime/Dropbox/PC/Documents/Coding/Memoire 2023/Datasets/Brain-Tumor-Dataset-RAW/Cropped_Image_Sets/test')):
    for file in sorted(os.listdir('C:/Users/alime/Dropbox/PC/Documents/Coding/Memoire 2023/Datasets/Brain-Tumor-Dataset-RAW/Cropped_Image_Sets/test/'+folder)):
        file_path = Home + '/' + folder + '/' + file

        file_name = file.split('.')[0]
        data.append([file_name, folder, file_path])

test_set = pd.DataFrame(data, columns=['File_Name', 'Folder', 'File_Path'])
print(test_set)
test_set.to_csv('Test_set.csv')
# Out:
#          File_Name                   Folder  \
# 0    G1005_cropped           glioma_cropped
# 1    G1023_cropped           glioma_cropped
# 2     G102_cropped           glioma_cropped
# 3    G1032_cropped           glioma_cropped
# 4    G1033_cropped           glioma_cropped
# ..             ...                      ...
# 457     P8_cropped  pituitary_tumor_cropped
# 458   P908_cropped  pituitary_tumor_cropped
# 459   P914_cropped  pituitary_tumor_cropped
# 460   P927_cropped  pituitary_tumor_cropped
# 461   P930_cropped  pituitary_tumor_cropped
#
#                                              File_Path
# 0    C:/Users/alime/Dropbox/PC/Documents/Coding/Mem...
# 1    C:/Users/alime/Dropbox/PC/Documents/Coding/Mem...
# 2    C:/Users/alime/Dropbox/PC/Documents/Coding/Mem...
# 3    C:/Users/alime/Dropbox/PC/Documents/Coding/Mem...
# 4    C:/Users/alime/Dropbox/PC/Documents/Coding/Mem...
# ..                                                 ...
# ...

# %%
dataframes = [train_set, val_set]
full_set = pd.concat(dataframes)
print("full_set", full_set)
full_set.to_csv('full_set.csv')
# Out:
# full_set          File_Name                   Folder  \
# 0    G1001_cropped           glioma_cropped
# 1    G1002_cropped           glioma_cropped
# 2    G1003_cropped           glioma_cropped
# 3    G1006_cropped           glioma_cropped
# 4    G1007_cropped           glioma_cropped
# ..             ...                      ...
# 453   P910_cropped  pituitary_tumor_cropped
# 454   P911_cropped  pituitary_tumor_cropped
# 455   P919_cropped  pituitary_tumor_cropped
# 456    P91_cropped  pituitary_tumor_cropped
# 457   P922_cropped  pituitary_tumor_cropped
#
#                                              File_Path
# 0    C:/Users/alime/Dropbox/PC/Documents/Coding/Mem...
# 1    C:/Users/alime/Dropbox/PC/Documents/Coding/Mem...
# 2    C:/Users/alime/Dropbox/PC/Documents/Coding/Mem...
# 3    C:/Users/alime/Dropbox/PC/Documents/Coding/Mem...
# 4    C:/Users/alime/Dropbox/PC/Documents/Coding/Mem...
# ..                                                 ...
# ...
